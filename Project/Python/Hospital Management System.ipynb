# %%
from IPython.display import clear_output  # this library is to clear the screen in jupyter


class Hospital:  # The class "Hospital" hold all the functions and attributes of this program
    def __init__(self,name,doctorsList,patientList): #This constructor initialize basic variables
        self.name = name #this string variable to hold the hospital name..
        self.doctors = doctorsList #this dictionary to hold the doctors details
        self.patients = patientList  #this dictionary to hold the patient details
        self.users = ("superadmin","admin","doctor","patient") #this tuple is to store the  roles
        self.currentLoginUser = {} #dictionary to hold current logged in user's details, currently we only have role
    
    
    #this function is to display welcome message
    def welcomeMessage(self):
        print("**************************************************************************************")
        print("******************** Hospital Management System **************************************")
        print(f"*********************** Welcome to {self.name}***************************************")
        print("**************************************************************************************")
    
    #this function is to log out from the system
    def logout(self):
        clear_output(wait=True) #clearing the screen
        print("**************************************************************************************")
        print("******************** Thak you for using the HMS **************************************")
        print(f"********************** You a re now successfully logged out *************************")
        print("**************************************************************************************")
    
    #this function is to login to the system - here we only use the role to login and then show the menu by logged role
    def login(self):
        self.welcomeMessage()
        print("Please enter the number for your role in the hospital management system")
        print("1 for Super Admin")
        print("2 for Admin")
        print("3 for Doctor")
        print("4 for Patient")
        return input()
    
    #this function helps to open the specific page chosen by the user
    def displayMenuByRole(self):
        clear_output(wait=True)
        self.welcomeMessage()
        print("You are logged in as", self.currentLoginUser["role"])
        print("***************************Please choose the menu to continue**************************")
        if self.currentLoginUser["role"] == "superadmin":
            print("1 for Display Doctor")
            print("2 Add Doctor")
            print("3 Add Patiant")
            print("5 Display Patient Details")
            print("***********************************************************************************")
        elif self.currentLoginUser["role"] == "admin":
            print("1 for Display Doctor")
            print("3 Add Patiant")
            print("5 Display Patient Details")
            print("***********************************************************************************")
        elif self.currentLoginUser["role"] == "doctor":
            print("5 Display Patient Details")
        elif self.currentLoginUser["role"] == "patient":
            print("5 Display Patient Details")
            print("***********************************************************************************")
        
        while(True):
            try:
                i = int(input())
                clear_output(wait=True)
                self.welcomeMessage()
                print("You are logged in as", self.currentLoginUser["role"])
                if (h.currentLoginUser["role"] == "superadmin") and (i in range(1,7)):
                    h.dsiplaySelectedPage(i)
                    break
                elif self.currentLoginUser["role"] == "admin" and i in range(1,5):
                    h.dsiplaySelectedPage(i)
                    break
                elif self.currentLoginUser["role"] == "doctor" and i==5:
                    h.dsiplaySelectedPage(i)
                    break
                elif self.currentLoginUser["role"] == "patient" and i==5:
                    h.dsiplaySelectedPage(i)
                    break
                else:
                    print("Invalid input, Please choose the correct menu")
            except Exception as error:
                print("Invalid input, Please choose the menu correctly. Error details:",error)
        
        e = input("Enter B to go back to main menu, E or any other key to logout and exit the program")
        if e=="B":
            h.displayMenuByRole()
        else:
            h.logout()
    
    #this funciton is to redirect to the specific screen based on the menu id passed
    def dsiplaySelectedPage(self, menuId):
        print("Inside dsiplaySelectedPage")
        if menuId == 1:
            self.displayDoctors() 
        elif menuId == 2:
            self.addDoctor()
        elif menuId == 3:
            self.addPatient()
        elif menuId == 5:
            self.dispalyPatient()
       
    
    #this function list down the doctor details int he doctor dictionary
    def displayDoctors(self):
        print("Our doctors are listed below:")
        for doctor in self.doctors:
            print(doctor["doctorId"],".",doctor["doctorName"],doctor["speciality"],doctor["qualification"])
           
    #this funciton is to add a new doctor
    def addDoctor(self):
        name = input("Please enter the name of the doctor")
        spec = input("Please enter the speciality")
        quali = input("Please enter the qualification")
        new_docId = max([doc["doctorId"] for doc in self.doctors]) + 1
        self.doctors.append({"doctorId":new_docId,"doctorName":name,"speciality":spec,"qualification":quali})
        self.displayDoctors()
    
    #this funciton is to add a new patient
    def addPatient(self):
        name = input("Please enter the name of the patient")
        age = input("Please enter the age of patient")
        address = input("Please enter the address of the patient")
        new_patientId = max([patient["patientId"] for patient in self.patients]) + 1
        self.patients.append({"patientId":new_patientId,"name":name,"age":age,"address":address})
        self.dispalyPatient()
    
    #this funciton is to display all patients
    def dispalyPatient(self):
        print("Patient database:")
        counter = 1
        
        for patient in self.patients:
            print(patient["patientId"],".",patient["name"],patient["age"],patient["address"])
            counter+=1
    
    

if __name__ == "__main__": #this is the main() to instantiate the class Hospital and then call the class functions
    
    doctorList = [{"doctorId":1,"doctorName":"Dr. Thomas Mathew","speciality":"ENT","qualification":"MBBS, MD ENT", "fee":500},
                  {"doctorId":2,"doctorName":"Dr. Jameela Hassan","speciality":"Gyne","qualification":"MBBS, MD", "fee":600},
                  {"doctorId":3,"doctorName":"Dr. Siva Sachi","speciality":"Pede","qualification":"MBBS, MD", "fee":300},
                  {"doctorId":4,"doctorName":"Dr. Salahuddin","speciality":"Gen Medicine","qualification":"MBBS, MD", "fee":200}]
    patientList = [{"patientId":1,"name":"Thasni","age":"35","address":"10 backel street"},
                  {"patientId":2,"name":"Himali","age":"34","address":"1121 Karthauzi utca"},
                  {"patientId":3,"name":"Riza","age":"33","address":"maliyekkal, ponnani"},
                  {"patientId":4,"name":"Roopa","age":"35","address":"101 Bur dubai"}]
    
    h = Hospital("MIMS Kozhikode",doctorList,patientList)   #creating the object of Hospital class
    
    
    while(True):
        try:
            i = int(h.login())
            h.currentLoginUser["role"] = h.users[i-1]
            break
        except:
            print("Invalid input, Please enter 1 for Super Admin 2 for Admin 3 for Doctor 4 for patient")
    
    h.displayMenuByRole()
# Out:
# **************************************************************************************
# ******************** Hospital Management System **************************************
# *********************** Welcome to MIMS Kozhikode***************************************
# **************************************************************************************
# You are logged in as superadmin
# ***************************Please choose the menu to continue**************************
# 1 for Display Doctor
# 2 Add Doctor
# 3 Add Patiant
# 5 Display Patient Details
# ***********************************************************************************
# B
# Invalid input, Please choose the menu correctly. Error details: invalid literal for int() with base 10: 'B'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6e4827fd9da2> in <module>
# ...
